# %%
print("======= WELCOME TO THINK BOT =======")
print("1. PLAY QUIZ")
print("2. ADD QUIZ QUESTIONS")
print("3. CREATE AN ACCOUNT")
print("4. SEE INSTRUCTIONS ON HOW TO PLAY THE GAME")
print("5. EXIT")
print("")
ch = int(input("Enter your choice : "))
def acc():
    PT = True
    while(PT == True):
        print("1. ADMIN")
        print("2. Create New Account")
        print("")
        ac = int(input("Enter Your Choice : "))
        if ac == 1:
            admin = input("Name : ")
            adminpass = input("Password : ")
            if adminpass == "THINKBOT" and admin == "BOT":
                print("Logged in SUCCESSFULLY")
                PT = False
            else:
                print("Name/Password Dosent Match!")
    
    
        else:
            name = input("Name :")
            p=True
            while (p==True):
                password1 = input("Password : ")
                password2 = input("Re-Enter Your Password : ")
                if password1 != password2 :
                    print("Password Dosent Match!")
                    print("Retype Your Password")
                else:
                    print("Account Successfully created")
                    p=False
                    PT=False
if ch == 1 or ch == 3:
    acc()

def c():
    print("")
    print("Round 1")
    print("")
    sum = 0
    print("Q1. Who developed the C proramming language?")
    print("A. Bjarne Stroustrup              C. Dennis Ritchie")
    print("B. James Gosling                  D. Ray Boyce")
    print("")
    ans = input("Enter the correct option : ")
    
    
    if ans == "c" or ans == "C" :
        print("Correct Option Selected")
        sum=sum+1
    else:
        print("Worng Answer Selected")
    
    print("")
    print("")
    print("Q2. A name having few letters , numbers and special character _(UnderScore) is called ")
    print("A. keywords                       C. tokens")
    print("B. reserved keywords              D. identifiers")
    print("")
    ans = input("Enter the correct option : ")
    
    
    if ans == "d" or ans == "D" :
        print("Correct Option Selected ")
        sum=sum+1
    else:
        print("Worng Option Selected ")
    
    print("")
    print("")
    print("Q3. Which one is not a reserve keyword in C Language? ")
    print("A. auto                           C. case")
    print("B. main                          D. register")
    print("")
    ans = input("Enter the correct option : ")
    
    
    if ans == "b" or ans == "B" :
        print("Correct Option Selected ")
        sum=sum+1
    else:
        print("Worng Option Selected ")
        
        
        
    print("")
    print("")
    print("Q4. A C variable name can start with a __")
    print("A. Number                           C. undersocre")
    print("B. Plus Sign (+)                    D. Asterisk(*)")
    print("")
    ans = input("Enter the correct option : ")
    
    
    if ans == "c" or ans == "C" :
        print("Correct Option Selected ")
        sum=sum+1
    else:
        print("Worng Option Selected ")
        
        
    print("")
    print("")
    print("Q5. Prototype of a function means ___")
    print("A. Name of Function                      C. Declaration of Function")
    print("B. Output of Function                    D. Input of a Function")
    print("")
    ans = input("Enter the correct option : ")
    
    
    if ans == "c" or ans == "C" :
        print("Correct Option Selected ")
        sum=sum+1
    else:
        print("Worng Option Selected ")
        
    print("Total Marks = ",  sum )
    print("")
        
   

# Round 2 C Language



    if sum<=3:
        print("Not Enough Score to go to Round 2. Better Luck Next Time :D")
    else:
        print("Welcome To The Round 2")
        print("")
        print("Q1. C program are converted into machine learning with the help of?")
        print("A. An Editor                  C. An Operating System")
        print("B. A Compiler                 D. None of the above")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "b" or ans == "B" :
            print("Correct Option Selected")
            sum=sum+1
        else:
            print("Worng Answer Selected")
    
        print("")
        print("")
        print("Q2. A C variable cannot start with ")
        print("A. An alphabet                       C. A special symbol other than underscore")
        print("B. A number                          D. both (b) and (c)")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "d" or ans == "D" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
    
        print("")
        print("")
        print("Q3. Which of the following is allowed in a C Arithmetic instruction ")
        print("A. []                          C. {}")
        print("B. ()                         D. None of the above")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "c" or ans == "C" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
                
        
        
        print("")
        print("")
        print("Q4.Which operators perform operations on data in binary level?")
        print("A. Logical operator                          C. Additional operators")
        print("B. Bitwise operator                          D. None of the above")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "b" or ans == "B" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
        
        
        print("")
        print("")
        print("Q5.The operator '&'is used for")
        print("A. Bitwise AND                      C. Logical AND")
        print("B. Bitwise OR                       D. Logical OR")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "a" or ans == "A" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
        
        print("Total Marks = ",  sum )
        print("")
        
#Round 3    

    if sum<=7:
        print("Not Enough Score to go to Round 3. Better Luck Next Time :D")
    else:
        print("Welcome To The Round 3")
        print("")
        print("Q1. Which are built-in data structures in C programming?")
        print("A. Arrays                    C.Files")
        print("B. Structures                D.  All of the above")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "d" or ans == "D" :
            print("Correct Option Selected")
            sum=sum+1
        else:
            print("Worng Answer Selected")
    
        print("")
        print("")
        print("Q2. The size of a character variable in C is")
        print("A. 8 bytes                         C. 2 bytes")
        print("B. 4 bytes                         D. 1 bytes")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "d" or ans == "D" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
    
        print("")
        print("")
        print("Q3. The keyword typedef is used to")
        print("A. create a type of function                          C. define the type of a variable")
        print("B. define the type of function                        D. create a new datatype name")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "d" or ans == "D" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
                
        
        
        print("")
        print("")
        print("Q4. By default a real number is treated as a")
        print("A. float                          C. long double")
        print("B. double                         D. integer")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "a" or ans == "A" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
        
        
        print("")
        print("")
        print("Q5.Which of the following is not a valid relational operator?")
        print("A. *                       C. >=")
        print("B. ==                      D. <=")
        print("")
        ans = input("Enter the correct option : ")
    
    
        if ans == "a" or ans == "A" :
            print("Correct Option Selected ")
            sum=sum+1
        else:
            print("Worng Option Selected ")
        
        print("Total Marks = ",  sum )
        
    if sum>10:
        print("Congratulations!!!!")
    else:
        print("Better Luck Nex Time !")

    
def py():
    print("Round 1")
    print("Round 2")
    print("Round 3")

    
def java():
    print("Round 1")
    print("Round 2")
    print("Round 3")
    
    
print("")
print("1. C Language Quiz")
print("2. Pyhton Quiz")
print("3. Java Quiz")
print("")
choice = int(input("Enter Your Choice : ") )
 
if choice == 1:
    print("Welcome to C Language Quiz")
    c()
    
    
    
elif choice == 2:
    print("Welcome to Python Quiz")
    py()
    
    
    
elif choice == 3:
    print("Welcome to Java Quiz")
    java()
    
    
    
else :
    print("Invalid Choice")
# Out:
# ======= WELCOME TO THINK BOT =======
# 1. PLAY QUIZ
# 2. ADD QUIZ QUESTIONS
# 3. CREATE AN ACCOUNT
# 4. SEE INSTRUCTIONS ON HOW TO PLAY THE GAME
# 5. EXIT
#
# Enter your choice : 1
# 1. ADMIN
# 2. Create New Account
#
# Enter Your Choice : 2
# Name :DARSHIL
# Password : darshil123
# Re-Enter Your Password : darshil123
# Account Successfully created
#
# 1. C Language Quiz
# 2. Pyhton Quiz
# 3. Java Quiz
#
# Enter Your Choice : 1
# Welcome to C Language Quiz
#
# Round 1
#
# Q1. Who developed the C proramming language?
# A. Bjarne Stroustrup              C. Dennis Ritchie
# B. James Gosling                  D. Ray Boyce
#
# Enter the correct option : c
# Correct Option Selected
#
#
# Q2. A name having few letters , numbers and special character _(UnderScore) is called
# A. keywords                       C. tokens
# B. reserved keywords              D. identifiers
#
# Enter the correct option : a
# Worng Option Selected
#
#
# Q3. Which one is not a reserve keyword in C Language?
# ...
